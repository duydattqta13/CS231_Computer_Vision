# %% [markdown]
# # Thông tin

# %% [markdown]
# 1.MSSV: 20520435
#
# 2.Họ tên: Nguyễn Duy Đạt
#
# 3.Bài tập: 6
#
# 4.Ngày thực hiện: 5/5/2022

# %% [markdown]
# # Sử dụng Graph Cut với ảnh Lionel-Messi.jpg, dogcat.jpg, camourflage_00166.jpg

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/CS231.M21.KHTN/Baitap/Baitap6/images/"
# Out:
# /content/drive/.shortcut-targets-by-id/13C37EedUSDnRymGA5rWpsqcry8w0txyr/CS231.M21.KHTN/Baitap/Baitap6/images

# %%
import cv2 as cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
def GraphSeg(path_filename, x, y, w, h):
  img = cv2.imread(path_filename)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  plt.imshow(img)
  plt.show()
  print(img.shape)
  mask = np.zeros(img.shape[:2], np.uint8)
  backgroundModel = np.zeros((1, 65), np.float64)
  foregroundModel = np.zeros((1, 65), np.float64)
  rectangle = (x, y, w, h)
  cv2.grabCut(img, mask, rectangle,
  backgroundModel, foregroundModel,
  5, cv2.GC_INIT_WITH_RECT)
  mask2 = np.where((mask == 2) | (mask == 0), 0, 1).astype('uint8')
  res = img * mask2[:, :, np.newaxis]
  plt.imshow(res)
  plt.show()
  res = cv2.cvtColor(res, cv2.COLOR_BGR2RGB)

# %%
dir = "Lionel-Messi.jpg"
GraphSeg(dir,240,0,250,600)
# Out:
# (427, 640, 3)

# %%
dir = "dogcat.jpg"
GraphSeg(dir,0,0,149,180)
# Out:
# (184, 234, 3)

# %%
dir = "camourflage_00166.jpg"
GraphSeg(dir,0,10,400,250)
# Out:
# (375, 592, 3)

# %% [markdown]
# -Hình camourflage_00166.jpg object với background khá giống nhau nên thuật toán Graph-Cut không hiệu quả.
